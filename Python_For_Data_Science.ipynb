# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
print(a)
print(type(a))
a.shape
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>
# (4,)

# %%
b = np.array([[1,2,3,4],[5,6,7,8]])
print(b)
b.shape
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]
# (2, 4)

# %%
b.T
# Out:
# array([[1, 5],
#        [2, 6],
#        [3, 7],
#        [4, 8]])

# %%
np.dot(b,b.T)
# Out:
# array([[ 30,  70],
#        [ 70, 174]])

# %%
np.random.randint(60,100,10)
# Out:
# array([96, 69, 93, 93, 81, 99, 96, 80, 77, 83])

# %%
matrix = np.random.randint(60,100,(5,5))
print(matrix)
# Out:
# [[75 92 94 71 91]
#  [79 83 80 91 96]
#  [61 74 82 61 69]
#  [67 71 76 71 82]
#  [74 78 68 63 88]]

# %%
np.min(matrix)
# Out:
# 61

# %%
a = np.array([0,1,-2,3,3,6,6,6,6,-8,10,10,10])
np.argmin(a)
# Out:
# 9

# %%
np.unique(a)
# Out:
# array([-8, -2,  0,  1,  3,  6, 10])

# %%
np.unique(a,return_counts=True)
# Out:
# (array([-8, -2,  0,  1,  3,  6, 10]),
#  array([1, 1, 1, 1, 2, 4, 3], dtype=int64))

# %%
matrix[2:4,1:4]
# Out:
# array([[74, 82, 61],
#        [71, 76, 71]])

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5])
y = x**2 + 3
print(x,y)
# Out:
# [1 2 3 4 5] [ 4  7 12 19 28]

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-darkgrid')

# %%
plt.plot(x,y,label="Stock Price")
plt.title("My Line Plot")
plt.xlabel("Timestamp")
plt.ylabel("Price in $")
plt.legend()
plt.show()

# %%
plt.scatter(x,y,label="Stock Price")
plt.title("My Scatter Plot")
plt.xlabel("Timestamp")
plt.ylabel("Price in $")
plt.legend()
plt.show()

# %% [markdown]
# # OpenCv

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('images/insipiration13.jpg')
rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
print(rgb_image.shape)
# Out:
# (310, 310, 3)

# %%
plt.imshow(rgb_image)
plt.axis('off')
plt.show()

# %%
# crop_image = rgb_image[0:300,150:0,:]
plt.imshow(rgb_image)
plt.show()

# %% [markdown]
# # Pandas

# %%
pokemons = {
    "Pokemon_Height":np.random.randint(1,100,5),
    "Pokemon_Weight":np.random.randint(50,150,5),
    "Pokemon_Power":np.random.randint(200,250,5)
}

# %%
pokemons
# Out:
# {'Pokemon_Height': array([14, 42, 30, 28, 92]),
#  'Pokemon_Weight': array([127, 114,  93, 130,  87]),
#  'Pokemon_Power': array([218, 245, 234, 207, 234])}

# %%
import pandas as pd

# %%
df = pd.DataFrame(pokemons)
print(df)
# Out:
#    Pokemon_Height  Pokemon_Weight  Pokemon_Power
# 0              14             127            218
# 1              42             114            245
# 2              30              93            234
# 3              28             130            207
# 4              92              87            234

# %%
df.head(n=3)
# Out:
#    Pokemon_Height  Pokemon_Weight  Pokemon_Power
# 0              14             127            218
# 1              42             114            245
# 2              30              93            234

# %%
print(df.columns)
# Out:
# Index(['Pokemon_Height', 'Pokemon_Weight', 'Pokemon_Power'], dtype='object')

# %%
df.to_csv('pokemon_data.csv',index=False)

# %%
df = pd.read_csv('pokemon_data.csv')
df.head()
# Out:
#    Pokemon_Height  Pokemon_Weight  Pokemon_Power
# 0              14             127            218
# 1              42             114            245
# 2              30              93            234
# 3              28             130            207
# 4              92              87            234

# %%
df.drop(columns=['Unnamed: 0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 df.drop(columns=['Unnamed: 0'])
#
# File c:\Users\RUSHABH\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
# ...

# %%
df.shape
# Out:
# (5, 3)
